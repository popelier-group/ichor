# %%
from ichor.core.files import *
# Out:
# Running cells with 'ichor_docs' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/Users/user/.venv/ichor_docs/bin/python -m pip install ipykernel -U --force-reinstall'
